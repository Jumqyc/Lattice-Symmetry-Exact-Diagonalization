# %%
import numpy as np
import matplotlib.pyplot as plt
from base import Lattice

# %%
square = Lattice(
    cell_info={
        ('A', 0): np.array([0.0, 0.0])},
    supercell_info=[
        (np.array([1.0, 0.0]), 3),
        (np.array([0.0, 1.0]), 3)
    ]
)

ax = square.plot()
plt.show
# Out:
# /home/jumqyc/Works/作业/SelfStudy/LattSymED/base.py:89: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
triangular = Lattice(
    cell_info={
        ('A', 0): np.array([0, 0]),
    },
    supercell_info=[
        (np.array([1, 0]), 5),
        (np.array([1/2, np.sqrt(3)/2]), 5)]
)
triangular.set_center_at(4)

ax = triangular.plot()
plt.show()

rotation_60 = np.array([[1/2, -np.sqrt(3)/2], [np.sqrt(3)/2, 1/2]])
print("Permutation for 60 degree rotation:", triangular.get_permutation_pt(rotation_60))
print("Permutation for x flip", triangular.get_permutation_pt(x_flip))
# Out:
# /home/jumqyc/Works/作业/SelfStudy/LattSymED/base.py:89: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# Permutation for 60 degree rotation: [20 16 12  8  4 21 17 13  9  0 22 18 14  5  1 23 19 10  6  2 24 15 11  7
#   3]
# Permutation for x flip [20 16 12  8  4 15 11  7  3 24 10  6  2 23 19  5  1 22 18 14  0 21 17 13
#   9]

# %%
hexagonal = Lattice(
    cell_info = {
        ('A',0): np.array([0, 0]),
        ('A',1): np.array([1, 0])
    },
    supercell_info = [
        (np.array([1.5, np.sqrt(3)/2]), 4),
        (np.array([1.5, -np.sqrt(3)/2]),4)
    ]
)
hexagonal.set_center_at(np.array([2,0]))

ax = hexagonal.plot()
# rotate by 60 degrees
plt.show()
print("Permutation for 60 degree rotation:", hexagonal.get_permutation_pt(rotation_60))
print("Permutation for x flip", hexagonal.get_permutation_pt(x_flip))
# Out:
# Permutation for 60 degree rotation: [27  2  3 10 11 18 19 26  1  8  9 16 17 24 25  0 15 22 23 30 31  6  7 14
#  21 28 29  4  5 12 13 20]
# Permutation for x flip [11 10  3  2 27 26 19 18  9  8  1  0 25 24 17 16 15 14  7  6 31 30 23 22
#  13 12  5  4 29 28 21 20]
